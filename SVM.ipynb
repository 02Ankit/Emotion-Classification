# %% [markdown]
# # LIBSVM options

# %%
# 'options':
#     -s svm_type : set type of SVM (default 0)
#         0 -- C-SVC
#         1 -- nu-SVC
#         2 -- one-class SVM
#         3 -- epsilon-SVR
#         4 -- nu-SVR
#     -t kernel_type : set type of kernel function (default 2)
#         0 -- linear: u'*v
#         1 -- polynomial: (gamma*u'*v + coef0)^degree
#         2 -- radial basis function: exp(-gamma*|u-v|^2)
#         3 -- sigmoid: tanh(gamma*u'*v + coef0)
#         4 -- precomputed kernel (kernel values in training_set_file)
#     -c cost : set the parameter C of C-SVC, epsilon-SVR, and nu-SVR (default 1)
#     -p epsilon : set the epsilon in loss function of epsilon-SVR (default 0.1)
#     -e epsilon : set tolerance of termination criterion (default 0.001)
#     -wi weight : set the parameter C of class i to weight*C, for C-SVC (default 1)

# %%
#importing necessary packaages
import numpy as np
import PIL
from PIL import Image
import os
import ntpath
import math
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from libsvm.svmutil import *

# %% [markdown]
# # Train Data

# %%
#Placing the input images into numpy array
allData = []       
happyData = []
sadData = []
N = 0
nHappy = 0
nSad = 0
directory = r"./emotion_classification/train"
for filename in os.scandir(directory):
    if filename.is_file():
        filename2 = directory + "/" + ntpath.basename(filename)
        img = Image.open(filename2).resize((100,100))
        npImg = np.array(img)
        flatArray = np.transpose(np.ravel(npImg))
        x = ntpath.basename(filename).split(".")
        if x[1] == "happy":
            happyData.append(list(flatArray))
            nHappy += 1
        else:
            sadData.append(list(flatArray))
            nSad += 1
N = nHappy + nSad
happyData = np.transpose(np.array(happyData))
sadData = np.transpose(np.array(sadData))
allData = np.concatenate((happyData,sadData),axis = 1)

print(allData.shape)
print(happyData.shape)
print(sadData.shape)
# Out:
# (10000, 20)
# (10000, 9)
# (10000, 11)

# %% [markdown]
# # Test Data

# %%
#Placing the test images into numpy array
happyDataTest = []
sadDataTest = []
N_test = 0
nHappyTest = 0
nSadTest = 0
directory = r"./emotion_classification/test"
for filename in os.scandir(directory):
    if filename.is_file():
        filename2 = directory + "/" + ntpath.basename(filename)
        img = Image.open(filename2).resize((100,100))
        np_img = np.array(img)/1
        flat_array = np.transpose(np.ravel(np_img))
        x = ntpath.basename(filename).split(".")
        if x[1] == "happy":
            happyDataTest.append(list(flat_array))
            nHappyTest += 1
        else:
            sadDataTest.append(list(flat_array))
            nSadTest += 1 
N_test = nHappyTest + nSadTest
happyDataTest = np.transpose(np.array(happyDataTest))
sadDataTest = np.transpose(np.array(sadDataTest))
allDataTest = np.concatenate((happyDataTest,sadDataTest),axis = 1)

print(allDataTest.shape)
print(happyDataTest.shape)
print(sadDataTest.shape)
# Out:
# (10000, 10)
# (10000, 6)
# (10000, 4)

# %% [markdown]
# # PART A: SVM Modelling

# %%
#Using SVM
#y -> list containing class labels for each data point; -1 for sad, and 1 for happy
y_happy = [1 for i in range(nHappy)]
y_sad = [-1 for i in range(nSad)]
y = y_happy + y_sad

# %%
y_happyTest = [1 for i in range(nHappyTest)]
y_sadTest = [-1 for i in range(nSadTest)]
y_test = y_happyTest + y_sadTest

# %%
class usingLIBSVM:
    def __init__(self, K, kernel, C, epsilon):
        self.parameters = '-t ' + str(kernel) + ' -c ' + str(C) + ' -p ' + str(epsilon)
        
#         # Reducing the dimension to K using PCA    TRAIN DATA
#         tempTrain = PCA(n_components = K)                  
#         self.reducedAllData = tempTrain.fit_transform(allData.T)  
        
#         # Reducing the dimension to K using PCA    TEST DATA
#         tempTest = PCA(n_components = K)                  
#         self.reducedAllDataTest = tempTest.fit_transform(allDataTest.T)  
        
        completeData = np.concatenate((allData,allDataTest),axis = 1)
        temp = PCA(n_components = K)                  
        reducedCompleteData = temp.fit_transform(completeData.T) 
        
        
        self.reducedAllData = reducedCompleteData[:N,]
        self.reducedAllDataTest = reducedCompleteData[N:,]
        
        self.SVMmodel = None
        
    def fit(self):
        self.SVMmodel = svm_train(y,self.reducedAllData, self.parameters)
    
    def predict(self):
        p_labels, p_acc, p_vals = svm_predict(y_test,self.reducedAllDataTest, self.SVMmodel)
        return p_labels
    def getReducedData(self):
        return self.reducedAllData, self.reducedAllDataTest

# %%
def findAccuracy(labels):
    correct = 0
    for i in range(N_test):
        if (y_test[i] == labels[i]):
            correct += 1
    return correct/N_test * 100

# %%
kernelType = ['linear', 'polynomial', 'RBF', 'Sigmoid']
maxAcc = 0
maxAccStr = []
maxAccValue = []
for k in range(14,19):
    for kernel in range(4):
        for c in range(4):
            for e in range(4):
                C = 10 ** c /100
                epsilon = 10 ** e /100
                tempObj = usingLIBSVM(k, kernel, C, epsilon)
                tempObj.fit()
                tempStr = "Kernel = " + kernelType[kernel] + "; C = " + str(C) + "; epsilon =" + str(epsilon) + "; K = " + str(k)
                print(tempStr)
                labels = tempObj.predict()
                print()
                accuracy = findAccuracy(labels)
                if (maxAcc <= accuracy):
                    maxAcc = accuracy
                    maxAccStr.append(tempStr)
                    maxAccValue.append(maxAcc)
                del tempObj
finalMaxAcc = max(maxAccValue)
print("Max Accuracy at the following settings with Accuracy = " + str(maxAcc))
for i in range(len(maxAccValue)):
    if (maxAccValue[i] == finalMaxAcc):
        print('\033[1m' + maxAccStr[i] + '\033[0m')
# Out:
# Kernel = linear; C = 0.01; epsilon =0.01; K = 14
# Accuracy = 70% (7/10) (classification)
#
# .......*...*
# optimization finished, #iter = 205
# nu = 0.000041
# obj = -0.000004, rho = 0.181395
# nSV = 13, nBSV = 0
# Total nSV = 13
# ......*...*
# optimization finished, #iter = 195
# nu = 0.000041
# obj = -0.000004, rho = 0.180002
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.01; epsilon =0.1; K = 14
# Accuracy = 70% (7/10) (classification)
#
# .......*...*
# optimization finished, #iter = 206
# nu = 0.000041
# Kernel = linear; C = 0.01; epsilon =1.0; K = 14
# Accuracy = 70% (7/10) (classification)
#
# obj = -0.000004, rho = 0.181770
# nSV = 13, nBSV = 0
# Total nSV = 13
# .Kernel = linear; C = 0.01; epsilon =10.0; K = 14
# ......*...*
# optimization finished, #iter = 200
# nu = 0.000041
# obj = -0.000004, rho = 0.184134
# nSV = 13, nBSV = 0
# Total nSV = 13
# Accuracy = 70% (7/10) (classification)
#
# .......*...*
# optimization finished, #iter = 207
# Kernel = linear; C = 0.1; epsilon =0.01; K = 14
# Accuracy = 70% (7/10) (classification)
#
# nu = 0.000004
# obj = -0.000004, rho = 0.177448
# nSV = 13, nBSV = 0
# Total nSV = 13
# .......*...*
# optimization finished, #iter = 212
# nu = 0.000004
# obj = -0.000004, rho = 0.191113
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.1; epsilon =0.1; K = 14
# Accuracy = 70% (7/10) (classification)
#
# .......*...*
# optimization finished, #iter = 209
# nu = 0.000004
# obj = -0.000004, rho = 0.175233
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.1; epsilon =1.0; K = 14
# Accuracy = 70% (7/10) (classification)
#
# ......*....*
# optimization finished, #iter = 206
# nu = 0.000004
# obj = -0.000004, rho = 0.180577
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.1; epsilon =10.0; K = 14
# Accuracy = 70% (7/10) (classification)
#
# ......*...*
# optimization finished, #iter = 196
# nu = 0.000000
# obj = -0.000004, rho = 0.178675
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 1.0; epsilon =0.01; K = 14
# Accuracy = 70% (7/10) (classification)
#
# .......*...*
# optimization finished, #iter = 208
# nu = 0.000000
# obj = -0.000004, rho = 0.174366
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 1.0; epsilon =0.1; K = 14
# Accuracy = 70% (7/10) (classification)
#
# .......*...*
# optimization finished, #iter = 201
# nu = 0.000000
# obj = -0.000004, rho = 0.179385
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 1.0; epsilon =1.0; K = 14
# Accuracy = 70% (7/10) (classification)
#
# .......*..*
# optimization finished, #iter = 196
# nu = 0.000000
# obj = -0.000004, rho = 0.175471
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 1.0; epsilon =10.0; K = 14
# Accuracy = 70% (7/10) (classification)
#
# ........*..*
# optimization finished, #iter = 212
# nu = 0.000000
# obj = -0.000004, rho = 0.180685
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 10.0; epsilon =0.01; K = 14
# Accuracy = 70% (7/10) (classification)
#
# ......*...*
# optimization finished, #iter = 193
# nu = 0.000000
# obj = -0.000004, rho = 0.181352
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 10.0; epsilon =0.1; K = 14
# Accuracy = 70% (7/10) (classification)
#
# ........*..*
# optimization finished, #iter = 202
# nu = 0.000000
# obj = -0.000004, rho = 0.181194
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 10.0; epsilon =1.0; K = 14
# Accuracy = 70% (7/10) (classification)
#
# ......*....*
# optimization finished, #iter = 201
# nu = 0.000000
# obj = -0.000004, rho = 0.180843
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 10.0; epsilon =10.0; K = 14
# Accuracy = 70% (7/10) (classification)
#
# ..*.*
# optimization finished, #iter = 74
# nu = 0.000000
# obj = -0.000000, rho = 0.401329
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =0.01; K = 14
# Accuracy = 50% (5/10) (classification)
#
# .Kernel = polynomial; C = 0.01; epsilon =0.1; K = 14
# Accuracy = 50% (5/10) (classification)
#
# .*.*
# optimization finished, #iter = 74
# nu = 0.000000
# obj = -0.000000, rho = 0.399967
# nSV = 19, nBSV = 0
# Total nSV = 19
# ..*..*
# optimization finished, #iter = 80
# nu = 0.000000
# obj = -0.000000, rho = 0.399673
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =1.0; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 77
# nu = 0.000000
# obj = -0.000000, rho = 0.400842
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =10.0; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ...*.*
# optimization finished, #iter = 80
# nu = 0.000000
# obj = -0.000000, rho = 0.401359
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =0.01; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 74
# nu = 0.000000
# obj = -0.000000, rho = 0.401831
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =0.1; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ...*.*
# optimization finished, #iter = 83
# nu = 0.000000
# obj = -0.000000, rho = 0.400494
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =1.0; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 73
# nu = 0.000000
# obj = -0.000000, rho = 0.399886
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =10.0; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 66
# nu = 0.000000
# obj = -0.000000, rho = 0.398406
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =0.01; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 70
# nu = 0.000000
# obj = -0.000000, rho = 0.400002
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =0.1; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ..*..*
# optimization finished, #iter = 84
# nu = 0.000000
# obj = -0.000000, rho = 0.403310
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =1.0; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 79
# nu = 0.000000
# obj = -0.000000, rho = 0.400119
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =10.0; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ...*.*
# optimization finished, #iter = 86
# nu = 0.000000
# obj = -0.000000, rho = 0.401009
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =0.01; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 76
# nu = 0.000000
# obj = -0.000000, rho = 0.401528
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =0.1; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 76
# nu = 0.000000
# obj = -0.000000, rho = 0.398818
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =1.0; K = 14
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 73
# nu = 0.000000
# obj = -0.000000, rho = 0.403708
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =10.0; K = 14
# Accuracy = 50% (5/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =0.01; K = 14
# Accuracy = 40% (4/10) (classification)
#
# *Kernel = RBF; C = 0.01; epsilon =0.1; K = 14
# .*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =1.0; K = 14
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =10.0; K = 14
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =0.01; K = 14
# Accuracy = 40% (4/10) (classification)
#
# .*Kernel = RBF; C = 0.1; epsilon =0.1; K = 14
#
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =1.0; K = 14
# Accuracy = 40% (4/10) (classification)
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =10.0; K = 14
# Accuracy = 40% (4/10) (classification)
#
# .Kernel = RBF; C = 1.0; epsilon =0.01; K = 14
# *
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =0.1; K = 14
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =1.0; K = 14
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =10.0; K = 14
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Kernel = RBF; C = 10.0; epsilon =0.01; K = 14
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Kernel = RBF; C = 10.0; epsilon =0.1; K = 14
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Kernel = RBF; C = 10.0; epsilon =1.0; K = 14
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# Kernel = RBF; C = 10.0; epsilon =10.0; K = 14
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Accuracy = 40% (4/10) (classification)
#
# Kernel = Sigmoid; C = 0.01; epsilon =0.01; K = 14
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 9
# nu = 0.900000
# obj = -0.179200, rho = 0.960000
# nSV = 18, nBSV = 18
# Total nSV = 18
# *
# optimization finished, #iter = 9
# nu = 0.900000
# obj = -0.179200, rho = 0.960000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =0.1; K = 14
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 9
# nu = 0.900000
# obj = -0.179200, rho = 0.960000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =1.0; K = 14
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 9
# nu = 0.900000
# obj = -0.179200, rho = 0.960000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =10.0; K = 14
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 9
# nu = 0.900000
# obj = -1.720000, rho = 0.600000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =0.01; K = 14
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 9
# nu = 0.900000
# obj = -1.720000, rho = 0.600000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =0.1; K = 14
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 9
# nu = 0.900000
# obj = -1.720000, rho = 0.600000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =1.0; K = 14
# Accuracy = 40% (4/10) (classification)
#
# *Kernel = Sigmoid; C = 0.1; epsilon =10.0; K = 14
# Accuracy = 40% (4/10) (classification)
#
#
# optimization finished, #iter = 9
# nu = 0.900000
# obj = -1.720000, rho = 0.600000
# nSV = 18, nBSV = 18
# Total nSV = 18
# *
# optimization finished, #iter = 18
# nu = 0.600000
# obj = -18.666667, rho = 0.333333
# nSV = 14, nBSV = 11
# Total nSV = 14
# Kernel = Sigmoid; C = 1.0; epsilon =0.01; K = 14
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 18
# nu = 0.600000
# obj = -18.666667, rho = 0.333333
# nSV = 14, nBSV = 11
# Total nSV = 14
# Kernel = Sigmoid; C = 1.0; epsilon =0.1; K = 14
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 18
# nu = 0.600000
# obj = -18.666667, rho = 0.333333
# nSV = 14, nBSV = 11
# Total nSV = 14
# Kernel = Sigmoid; C = 1.0; epsilon =1.0; K = 14
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 18
# Kernel = Sigmoid; C = 1.0; epsilon =10.0; K = 14
# nu = 0.600000
# obj = -18.666667, rho = 0.333333
# nSV = 14, nBSV = 11
# Total nSV = 14
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 14
# Kernel = Sigmoid; C = 10.0; epsilon =0.01; K = 14
# Accuracy = 80% (8/10) (classification)
#
# nu = 0.505000
# obj = -1100.500000, rho = 0.000000
# nSV = 12, nBSV = 10
# Total nSV = 12
# *
# optimization finished, #iter = 14
# nu = 0.505000
# obj = -1100.500000, rho = 0.000000
# nSV = 12, nBSV = 10
# Total nSV = 12
# Kernel = Sigmoid; C = 10.0; epsilon =0.1; K = 14
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 14
# nu = 0.505000
# obj = -1100.500000, rho = 0.000000
# nSV = 12, nBSV = 10
# Total nSV = 12
# Kernel = Sigmoid; C = 10.0; epsilon =1.0; K = 14
# Accuracy = 80% (8/10) (classification)
#
# *Kernel = Sigmoid; C = 10.0; epsilon =10.0; K = 14
#
# optimization finished, #iter = 14
# nu = 0.505000
# obj = -1100.500000, rho = 0.000000
# nSV = 12, nBSV = 10
# Total nSV = 12
# Accuracy = 80% (8/10) (classification)
#
# ..Kernel = linear; C = 0.01; epsilon =0.01; K = 15
# .....*...*
# optimization finished, #iter = 216
# nu = 0.000038
# obj = -0.000004, rho = 0.212428
# nSV = 13, nBSV = 0
# Total nSV = 13
# Accuracy = 90% (9/10) (classification)
#
# .......*..*
# optimization finished, #iter = 193
# nu = 0.000039
# obj = -0.000004, rho = 0.208274
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.01; epsilon =0.1; K = 15
# Accuracy = 90% (9/10) (classification)
#
# .......*..*
# optimization finished, #iter = 198
# nu = 0.000039
# obj = -0.000004, rho = 0.208173
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.01; epsilon =1.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
# ........*...*
# optimization finished, #iter = 221
# nu = 0.000038
# obj = -0.000004, rho = 0.208316
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.01; epsilon =10.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
# .......*...*
# optimization finished, #iter = 212
# nu = 0.000004
# obj = -0.000004, rho = 0.207965
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.1; epsilon =0.01; K = 15
# Accuracy = 90% (9/10) (classification)
#
# .......*....*Kernel = linear; C = 0.1; epsilon =0.1; K = 15
#
# optimization finished, #iter = 222
# nu = 0.000004
# obj = -0.000004, rho = 0.209831
# nSV = 13, nBSV = 0
# Total nSV = 13
# Accuracy = 90% (9/10) (classification)
#
# .......*...*
# optimization finished, #iter = 212
# nu = 0.000004
# obj = -0.000004, rho = 0.208325
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.1; epsilon =1.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
# ........*...*
# optimization finished, #iter = 221
# nu = 0.000004
# obj = -0.000004, rho = 0.209202
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.1; epsilon =10.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
# .......*...*
# optimization finished, #iter = 214
# nu = 0.000000
# obj = -0.000004, rho = 0.208965
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 1.0; epsilon =0.01; K = 15
# Accuracy = 90% (9/10) (classification)
#
# .......*...*
# optimization finished, #iter = 202
# nu = 0.000000
# obj = -0.000004, rho = 0.201684
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 1.0; epsilon =0.1; K = 15
# Accuracy = 90% (9/10) (classification)
#
# ..Kernel = linear; C = 1.0; epsilon =1.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
# ......*...*
# optimization finished, #iter = 221
# nu = 0.000000
# obj = -0.000004, rho = 0.208247
# nSV = 13, nBSV = 0
# Total nSV = 13
# .......*...*
# optimization finished, #iter = 204
# nu = 0.000000
# obj = -0.000004, rho = 0.208334
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 1.0; epsilon =10.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
# .......*...*
# optimization finished, #iter = 205
# nu = 0.000000
# obj = -0.000004, rho = 0.206454
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 10.0; epsilon =0.01; K = 15
# Accuracy = 90% (9/10) (classification)
#
# ........*..*
# optimization finished, #iter = 215
# nu = 0.000000
# obj = -0.000004, rho = 0.208886
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 10.0; epsilon =0.1; K = 15
# Accuracy = 90% (9/10) (classification)
#
# .Kernel = linear; C = 10.0; epsilon =1.0; K = 15
# .......*..*
# optimization finished, #iter = 209
# nu = 0.000000
# obj = -0.000004, rho = 0.208134
# nSV = 13, nBSV = 0
# Total nSV = 13
# Accuracy = 90% (9/10) (classification)
# .......*...*
# optimization finished, #iter = 207
# Kernel = linear; C = 10.0; epsilon =10.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
# nu = 0.000000
# obj = -0.000004, rho = 0.209133
# nSV = 13, nBSV = 0
# Total nSV = 13
# ..*.*
# optimization finished, #iter = 75
# nu = 0.000000
# obj = -0.000000, rho = 0.382252
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =0.01; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 79
# nu = 0.000000
# obj = -0.000000, rho = 0.382931
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =0.1; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ..*Kernel = polynomial; C = 0.01; epsilon =1.0; K = 15
# .*
# optimization finished, #iter = 78
# nu = 0.000000
# obj = -0.000000, rho = 0.382913
# nSV = 19, nBSV = 0
# Total nSV = 19
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 79
# nu = 0.000000
# obj = -0.000000, rho = 0.386159
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =10.0; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ..*.Kernel = polynomial; C = 0.1; epsilon =0.01; K = 15
# *
# optimization finished, #iter = 74
# nu = 0.000000
# obj = -0.000000, rho = 0.383562
# nSV = 19, nBSV = 0
# Total nSV = 19
# Accuracy = 50% (5/10) (classification)
#
# ...*.*
# optimization finished, #iter = 85
# nu = 0.000000
# obj = -0.000000, rho = 0.383944
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =0.1; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 77
# nu = 0.000000
# obj = -0.000000, rho = 0.383274
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =1.0; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ...*
# optimization finished, #iter = 79
# nu = 0.000000
# obj = -0.000000, rho = 0.381241
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =10.0; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 68
# nu = 0.000000
# obj = -0.000000, rho = 0.382874
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =0.01; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 79
# nu = 0.000000
# obj = -0.000000, rho = 0.382667
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =0.1; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 74
# nu = 0.000000
# obj = -0.000000, rho = 0.382756
# nSV = 19, nBSV = 0
# Kernel = polynomial; C = 1.0; epsilon =1.0; K = 15
# Total nSV = 19
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 78
# nu = 0.000000
# obj = -0.000000, rho = 0.383388
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =10.0; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ..Kernel = polynomial; C = 10.0; epsilon =0.01; K = 15
# Accuracy = 50% (5/10) (classification)
#
# *.*
# optimization finished, #iter = 75
# nu = 0.000000
# obj = -0.000000, rho = 0.382924
# nSV = 19, nBSV = 0
# Total nSV = 19
# ..*.*
# optimization finished, #iter = 78
# nu = 0.000000
# obj = -0.000000, rho = 0.383890
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =0.1; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ..*..*
# optimization finished, #iter = 83
# nu = 0.000000
# obj = -0.000000, rho = 0.384501
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =1.0; K = 15
# Accuracy = 50% (5/10) (classification)
#
# ..*..*
# optimization finished, #iter = 82
# nu = 0.000000
# obj = -0.000000, rho = 0.382162
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =10.0; K = 15
# Accuracy = 50% (5/10) (classification)
#
# *Kernel = RBF; C = 0.01; epsilon =0.01; K = 15
# .*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =0.1; K = 15
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =1.0; K = 15
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =10.0; K = 15
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =0.01; K = 15
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =0.1; K = 15
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =1.0; K = 15
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =10.0; K = 15
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =0.01; K = 15
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =0.1; K = 15
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =1.0; K = 15
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =10.0; K = 15
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Kernel = RBF; C = 10.0; epsilon =0.01; K = 15
# Accuracy = 40% (4/10) (classification)
#
# ..*.*Kernel = RBF; C = 10.0; epsilon =0.1; K = 15
#
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Accuracy = 40% (4/10) (classification)
#
# Kernel = RBF; C = 10.0; epsilon =1.0; K = 15..*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
#
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Kernel = RBF; C = 10.0; epsilon =10.0; K = 15
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179400, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =0.01; K = 15
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179400, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =0.1; K = 15
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179400, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =1.0; K = 15
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179400, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =10.0; K = 15
# Accuracy = 40% (4/10) (classification)
#
# Kernel = Sigmoid; C = 0.1; epsilon =0.01; K = 15*
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.740000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
#
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.740000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =0.1; K = 15
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.740000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =1.0; K = 15
# Accuracy = 40% (4/10) (classification)
# *
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.740000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =10.0; K = 15
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =0.01; K = 15
# Accuracy = 90% (9/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =0.1; K = 15
# Accuracy = 90% (9/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =1.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =10.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
# *
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Kernel = Sigmoid; C = 10.0; epsilon =0.01; K = 15
# Accuracy = 90% (9/10) (classification)
#
# *
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Kernel = Sigmoid; C = 10.0; epsilon =0.1; K = 15
# Accuracy = 90% (9/10) (classification)
#
# *
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Kernel = Sigmoid; C = 10.0; epsilon =1.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
# *Kernel = Sigmoid; C = 10.0; epsilon =10.0; K = 15
# Accuracy = 90% (9/10) (classification)
#
#
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# .......*...*
# optimization finished, #iter = 204
# nu = 0.000037
# obj = -0.000004, rho = 0.245028
# nSV = 14, nBSV = 0
# Kernel = linear; C = 0.01; epsilon =0.01; K = 16
# Accuracy = 90% (9/10) (classification)
#
# Total nSV = 14
# .......*..*
# optimization finished, #iter = 195
# nu = 0.000037
# obj = -0.000004, rho = 0.243292
# nSV = 14, nBSV = 0
# Kernel = linear; C = 0.01; epsilon =0.1; K = 16
# Accuracy = 90% (9/10) (classification)
#
# Total nSV = 14
# ......*.....*
# optimization finished, #iter = 224
# nu = 0.000038
# obj = -0.000004, rho = 0.243161
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 0.01; epsilon =1.0; K = 16
# Accuracy = 90% (9/10) (classification)
#
# .......*....*
# optimization finished, #iter = 221
# nu = 0.000037
# obj = -0.000004, rho = 0.245305
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 0.01; epsilon =10.0; K = 16
# Accuracy = 90% (9/10) (classification)
#
# .....*....*
# optimization finished, #iter = 180
# nu = 0.000004
# obj = -0.000004, rho = 0.244416
# Kernel = linear; C = 0.1; epsilon =0.01; K = 16
# nSV = 14, nBSV = 0
# Total nSV = 14
# Accuracy = 90% (9/10) (classification)
#
# .....*....*
# optimization finished, #iter = 187
# nu = 0.000004
# obj = -0.000004, rho = 0.246381
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 0.1; epsilon =0.1; K = 16
# Accuracy = 90% (9/10) (classification)
#
# ......*...*
# optimization finished, #iter = 198
# nu = 0.000004
# obj = -0.000004, rho = 0.244603
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 0.1; epsilon =1.0; K = 16
# Accuracy = 90% (9/10) (classification)
#
# ........*...*
# optimization finished, #iter = 225
# nu = 0.000004
# obj = -0.000004, rho = 0.244200
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 0.1; epsilon =10.0; K = 16
# Accuracy = 90% (9/10) (classification)
#
# .....Kernel = linear; C = 1.0; epsilon =0.01; K = 16
# Accuracy = 90% (9/10) (classification)
#
# ..*..*
# optimization finished, #iter = 196
# nu = 0.000000
# obj = -0.000004, rho = 0.244552
# nSV = 14, nBSV = 0
# Total nSV = 14
# ........*.*
# optimization finished, #iter = 196
# nu = 0.000000
# obj = -0.000004, rho = 0.244751
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 1.0; epsilon =0.1; K = 16
# Accuracy = 90% (9/10) (classification)
#
# .......*..*
# optimization finished, #iter = 193
# nu = 0.000000
# obj = -0.000004, rho = 0.245401
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 1.0; epsilon =1.0; K = 16
# Accuracy = 90% (9/10) (classification)
#
# .......*...*
# optimization finished, #iter = 212
# nu = 0.000000
# obj = -0.000004, rho = 0.244007
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 1.0; epsilon =10.0; K = 16
# Accuracy = 90% (9/10) (classification)
#
# .......*...*
# optimization finished, #iter = 213
# nu = 0.000000
# obj = -0.000004, rho = 0.246286
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 10.0; epsilon =0.01; K = 16
# Accuracy = 90% (9/10) (classification)
#
# ......*.....*
# optimization finished, #iter = 230
# nu = 0.000000
# obj = -0.000004, rho = 0.242880
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 10.0; epsilon =0.1; K = 16
# Accuracy = 90% (9/10) (classification)
#
# .......*..*
# optimization finished, #iter = 192
# nu = 0.000000
# obj = -0.000004, rho = 0.246011
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 10.0; epsilon =1.0; K = 16
# Accuracy = 90% (9/10) (classification)
#
# .....*....*
# optimization finished, #iter = 193
# nu = 0.000000
# obj = -0.000004, rho = 0.243359
# nSV = 14, nBSV = 0
# Total nSV = 14
# Kernel = linear; C = 10.0; epsilon =10.0; K = 16
# Accuracy = 90% (9/10) (classification)
#
# ..*.*
# optimization finished, #iter = 71
# nu = 0.000000
# obj = -0.000000, rho = 0.374525
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =0.01; K = 16
# Accuracy = 50% (5/10) (classification)
#
# .Kernel = polynomial; C = 0.01; epsilon =0.1; K = 16
# Accuracy = 50% (5/10) (classification)
#
# ..*
# optimization finished, #iter = 78
# nu = 0.000000
# obj = -0.000000, rho = 0.374188
# nSV = 19, nBSV = 0
# Total nSV = 19
# ..*.*
# optimization finished, #iter = 71
# nu = 0.000000
# obj = -0.000000, rho = 0.373659
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =1.0; K = 16
# Accuracy = 50% (5/10) (classification)
#
# .Kernel = polynomial; C = 0.01; epsilon =10.0; K = 16
# .*..*
# optimization finished, #iter = 80
# nu = 0.000000
# obj = -0.000000, rho = 0.374539
# nSV = 19, nBSV = 0
# Total nSV = 19
# Accuracy = 50% (5/10) (classification)
#
# ..Kernel = polynomial; C = 0.1; epsilon =0.01; K = 16
# *.*
# optimization finished, #iter = 73
# nu = 0.000000
# obj = -0.000000, rho = 0.374090
# nSV = 19, nBSV = 0
# Total nSV = 19
# Accuracy = 50% (5/10) (classification)
#
# .Kernel = polynomial; C = 0.1; epsilon =0.1; K = 16
# Accuracy = 50% (5/10) (classification)
#
# .*.*
# optimization finished, #iter = 68
# nu = 0.000000
# obj = -0.000000, rho = 0.373921
# nSV = 19, nBSV = 0
# Total nSV = 19
# ..*.*
# optimization finished, #iter = 72
# nu = 0.000000
# obj = -0.000000, rho = 0.373753
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =1.0; K = 16
# Accuracy = 50% (5/10) (classification)
#
# ..*..*
# optimization finished, #iter = 81
# nu = 0.000000
# obj = -0.000000, rho = 0.374691
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =10.0; K = 16
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 76
# nu = 0.000000
# obj = -0.000000, rho = 0.373623
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =0.01; K = 16
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 74
# nu = 0.000000
# obj = -0.000000, rho = 0.373467
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =0.1; K = 16
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 74
# nu = 0.000000
# obj = -0.000000, rho = 0.374106
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =1.0; K = 16
# Accuracy = 50% (5/10) (classification)
#
# ...*.*
# optimization finished, #iter = 80
# nu = 0.000000
# obj = -0.000000, rho = 0.372647
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =10.0; K = 16
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 71
# nu = 0.000000
# obj = -0.000000, rho = 0.376169
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =0.01; K = 16
# Accuracy = 50% (5/10) (classification)
#
# ...*.*
# optimization finished, #iter = 82
# nu = 0.000000
# obj = -0.000000, rho = 0.374024
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =0.1; K = 16
# Accuracy = 50% (5/10) (classification)
# ..*..*
# optimization finished, #iter = 82
# nu = 0.000000
# obj = -0.000000, rho = 0.373636
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =1.0; K = 16
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 78
# nu = 0.000000
# obj = -0.000000, rho = 0.375015
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =10.0; K = 16
# Accuracy = 50% (5/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =0.01; K = 16
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =0.1; K = 16
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =1.0; K = 16
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =10.0; K = 16
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =0.01; K = 16
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =0.1; K = 16
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =1.0; K = 16
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =10.0; K = 16
# Accuracy = 40% (4/10) (classification)
#
# .*Kernel = RBF; C = 1.0; epsilon =0.01; K = 16
#
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =0.1; K = 16
# Accuracy = 40% (4/10) (classification)
#
# .*Kernel = RBF; C = 1.0; epsilon =1.0; K = 16
# Accuracy = 40% (4/10) (classification)
#
#
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# .Kernel = RBF; C = 1.0; epsilon =10.0; K = 16
# *
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Accuracy = 40% (4/10) (classification)
#
# .Kernel = RBF; C = 10.0; epsilon =0.01; K = 16
# .*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Kernel = RBF; C = 10.0; epsilon =0.1; K = 16
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Kernel = RBF; C = 10.0; epsilon =1.0; K = 16
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Kernel = RBF; C = 10.0; epsilon =10.0; K = 16
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179200, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =0.01; K = 16
# Accuracy = 40% (4/10) (classification)
#
# *Kernel = Sigmoid; C = 0.01; epsilon =0.1; K = 16
#
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179200, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 11
# nu = 0.900000
# Kernel = Sigmoid; C = 0.01; epsilon =1.0; K = 16
# obj = -0.179200, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179200, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =10.0; K = 16
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.720000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =0.01; K = 16
# Accuracy = 40% (4/10) (classification)
#
# *Kernel = Sigmoid; C = 0.1; epsilon =0.1; K = 16
#
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.720000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.720000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =1.0; K = 16
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.720000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =10.0; K = 16
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =0.01; K = 16
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =0.1; K = 16
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =1.0; K = 16
# Accuracy = 80% (8/10) (classification)
#
# *Kernel = Sigmoid; C = 1.0; epsilon =10.0; K = 16
# Accuracy = 80% (8/10) (classification)
#
#
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# *
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Kernel = Sigmoid; C = 10.0; epsilon =0.01; K = 16
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Kernel = Sigmoid; C = 10.0; epsilon =0.1; K = 16
# Accuracy = 80% (8/10) (classification)
#
# *Kernel = Sigmoid; C = 10.0; epsilon =1.0; K = 16
#
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Kernel = Sigmoid; C = 10.0; epsilon =10.0; K = 16
# Accuracy = 80% (8/10) (classification)
#
# ..Kernel = linear; C = 0.01; epsilon =0.01; K = 17
# .*.*
# optimization finished, #iter = 91
# nu = 0.000031
# obj = -0.000003, rho = 0.151691
# nSV = 13, nBSV = 0
# Total nSV = 13
# Accuracy = 90% (9/10) (classification)
#
# ...*.*Kernel = linear; C = 0.01; epsilon =0.1; K = 17
#
# optimization finished, #iter = 95
# nu = 0.000031
# obj = -0.000003, rho = 0.152866
# nSV = 13, nBSV = 0
# Total nSV = 13
# Accuracy = 90% (9/10) (classification)
#
# ..*..*
# optimization finished, #iter = 90
# nu = 0.000031
# obj = -0.000003, rho = 0.151839
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.01; epsilon =1.0; K = 17
# Accuracy = 90% (9/10) (classification)
#
# .Kernel = linear; C = 0.01; epsilon =10.0; K = 17
# .*..*
# optimization finished, #iter = 87
# nu = 0.000031
# obj = -0.000003, rho = 0.151446
# nSV = 13, nBSV = 0
# Total nSV = 13
# Accuracy = 90% (9/10) (classification)
#
# ..*..Kernel = linear; C = 0.1; epsilon =0.01; K = 17
# *
# optimization finished, #iter = 89
# nu = 0.000003
# obj = -0.000003, rho = 0.151571
# nSV = 13, nBSV = 0
# Total nSV = 13
# Accuracy = 90% (9/10) (classification)
#
# ..*.*
# optimization finished, #iter = 65
# nu = 0.000003
# obj = -0.000003, rho = 0.151361
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.1; epsilon =0.1; K = 17
# Accuracy = 90% (9/10) (classification)
# ..*..*
# optimization finished, #iter = 94
# nu = 0.000003
# obj = -0.000003, rho = 0.149760
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.1; epsilon =1.0; K = 17
# Accuracy = 90% (9/10) (classification)
#
# ..*.*
# optimization finished, #iter = 66
# nu = 0.000003
# obj = -0.000003, rho = 0.151769
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 0.1; epsilon =10.0; K = 17
# Accuracy = 90% (9/10) (classification)
#
# ...*.*
# optimization finished, #iter = 98
# nu = 0.000000
# obj = -0.000003, rho = 0.150813
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 1.0; epsilon =0.01; K = 17
# Accuracy = 90% (9/10) (classification)
#
# .Kernel = linear; C = 1.0; epsilon =0.1; K = 17
# Accuracy = 90% (9/10) (classification)
#
# ..*.*
# optimization finished, #iter = 89
# nu = 0.000000
# obj = -0.000003, rho = 0.149499
# nSV = 13, nBSV = 0
# Total nSV = 13
# ..*..*
# optimization finished, #iter = 85
# nu = 0.000000
# obj = -0.000003, rho = 0.151305
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 1.0; epsilon =1.0; K = 17
# Accuracy = 90% (9/10) (classification)
#
# .Kernel = linear; C = 1.0; epsilon =10.0; K = 17
# .*..*
# optimization finished, #iter = 90
# nu = 0.000000
# obj = -0.000003, rho = 0.151273
# nSV = 13, nBSV = 0
# Total nSV = 13
# Accuracy = 90% (9/10) (classification)
#
# ..*.*
# optimization finished, #iter = 76
# nu = 0.000000
# obj = -0.000003, rho = 0.151326
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 10.0; epsilon =0.01; K = 17
# Accuracy = 90% (9/10) (classification)
#
# .Kernel = linear; C = 10.0; epsilon =0.1; K = 17
# Accuracy = 90% (9/10) (classification)
#
# ..*.*
# optimization finished, #iter = 94
# nu = 0.000000
# obj = -0.000003, rho = 0.151596
# nSV = 13, nBSV = 0
# Total nSV = 13
# ..*.*
# optimization finished, #iter = 66
# nu = 0.000000
# obj = -0.000003, rho = 0.152120
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 10.0; epsilon =1.0; K = 17
# Accuracy = 90% (9/10) (classification)
#
# ...*.*
# optimization finished, #iter = 92
# nu = 0.000000
# obj = -0.000003, rho = 0.151052
# nSV = 13, nBSV = 0
# Total nSV = 13
# Kernel = linear; C = 10.0; epsilon =10.0; K = 17
# Accuracy = 90% (9/10) (classification)
#
# ..*.*
# optimization finished, #iter = 76
# nu = 0.000000
# obj = -0.000000, rho = 0.352753
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =0.01; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 65
# nu = 0.000000
# obj = -0.000000, rho = 0.353346
# Kernel = polynomial; C = 0.01; epsilon =0.1; K = 17
# nSV = 19, nBSV = 0
# Total nSV = 19
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 66
# nu = 0.000000
# obj = -0.000000, rho = 0.352550
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =1.0; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 71
# nu = 0.000000
# obj = -0.000000, rho = 0.353122
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =10.0; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 68
# nu = 0.000000
# obj = -0.000000, rho = 0.353083
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =0.01; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 71
# nu = 0.000000
# obj = -0.000000, rho = 0.352652
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =0.1; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 70
# nu = 0.000000
# obj = -0.000000, rho = 0.351754
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =1.0; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 73
# nu = 0.000000
# obj = -0.000000, rho = 0.352451
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =10.0; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 67
# nu = 0.000000
# obj = -0.000000, rho = 0.352536
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =0.01; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 71
# nu = 0.000000
# obj = -0.000000, rho = 0.353535
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =0.1; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 75
# nu = 0.000000
# obj = -0.000000, rho = 0.353180
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =1.0; K = 17
# Accuracy = 50% (5/10) (classification)
#
# .Kernel = polynomial; C = 1.0; epsilon =10.0; K = 17
# Accuracy = 50% (5/10) (classification)
#
# .*.*
# optimization finished, #iter = 72
# nu = 0.000000
# obj = -0.000000, rho = 0.352874
# nSV = 19, nBSV = 0
# Total nSV = 19
# ..*.*
# optimization finished, #iter = 66
# nu = 0.000000
# obj = -0.000000, rho = 0.352804
# nSV = 19, nBSV = 0
# Kernel = polynomial; C = 10.0; epsilon =0.01; K = 17
# Total nSV = 19
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 65
# nu = 0.000000
# obj = -0.000000, rho = 0.352741
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =0.1; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 71
# nu = 0.000000
# obj = -0.000000, rho = 0.353515
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =1.0; K = 17
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 68
# nu = 0.000000
# obj = -0.000000, rho = 0.354695
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =10.0; K = 17
# Accuracy = 50% (5/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =0.01; K = 17
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =0.1; K = 17
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =1.0; K = 17
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =10.0; K = 17
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =0.01; K = 17
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# ...
# ...*..*
# optimization finished, #iter = 155
# nu = 0.000002
# obj = -0.000002, rho = -0.184859
# nSV = 15, nBSV = 0
# Total nSV = 15
# Accuracy = 90% (9/10) (classification)
#
# ....*Kernel = linear; C = 0.1; epsilon =0.1; K = 18
# ...*
# optimization finished, #iter = 154
# nu = 0.000002
# obj = -0.000002, rho = -0.184003
# nSV = 15, nBSV = 0
# Total nSV = 15
# Accuracy = 90% (9/10) (classification)
#
# ...Kernel = linear; C = 0.1; epsilon =1.0; K = 18
# .*...*
# optimization finished, #iter = 144
# nu = 0.000002
# obj = -0.000002, rho = -0.183424
# nSV = 15, nBSV = 0
# Total nSV = 15
# Accuracy = 90% (9/10) (classification)
#
# .....*Kernel = linear; C = 0.1; epsilon =10.0; K = 18
# ..*
# optimization finished, #iter = 153
# nu = 0.000002
# obj = -0.000002, rho = -0.184651
# nSV = 15, nBSV = 0
# Total nSV = 15
# Accuracy = 90% (9/10) (classification)
#
# .....*...*
# optimization finished, #iter = 164
# nu = 0.000000
# obj = -0.000002, rho = -0.184800
# nSV = 15, nBSV = 0
# Total nSV = 15
# Kernel = linear; C = 1.0; epsilon =0.01; K = 18
# Accuracy = 90% (9/10) (classification)
#
# ....*...*
# optimization finished, #iter = 147
# nu = 0.000000
# obj = -0.000002, rho = -0.184738
# nSV = 15, nBSV = 0
# Total nSV = 15
# Kernel = linear; C = 1.0; epsilon =0.1; K = 18
# Accuracy = 90% (9/10) (classification)
#
# .....*..*
# optimization finished, #iter = 154
# nu = 0.000000
# obj = -0.000002, rho = -0.183764
# nSV = 15, nBSV = 0
# Total nSV = 15
# Kernel = linear; C = 1.0; epsilon =1.0; K = 18
# Accuracy = 90% (9/10) (classification)
#
# ....*...*
# optimization finished, #iter = 144
# nu = 0.000000
# obj = -0.000002, rho = -0.184895
# nSV = 15, nBSV = 0
# Total nSV = 15
# Kernel = linear; C = 1.0; epsilon =10.0; K = 18
# Accuracy = 90% (9/10) (classification)
#
# .....*..*
# optimization finished, #iter = 144
# nu = 0.000000
# obj = -0.000002, rho = -0.184601
# nSV = 15, nBSV = 0
# Total nSV = 15
# Kernel = linear; C = 10.0; epsilon =0.01; K = 18
# Accuracy = 90% (9/10) (classification)
#
# .....*..*
# optimization finished, #iter = 155
# nu = 0.000000
# obj = -0.000002, rho = -0.184537
# nSV = 15, nBSV = 0
# Total nSV = 15
# Kernel = linear; C = 10.0; epsilon =0.1; K = 18
# Accuracy = 90% (9/10) (classification)
#
# .....*...*
# optimization finished, #iter = 162
# nu = 0.000000
# obj = -0.000002, rho = -0.184064
# nSV = 15, nBSV = 0
# Total nSV = 15
# Kernel = linear; C = 10.0; epsilon =1.0; K = 18
# Accuracy = 90% (9/10) (classification)
#
# .....*..*
# optimization finished, #iter = 149
# nu = 0.000000
# obj = -0.000002, rho = -0.184838
# nSV = 15, nBSV = 0
# Total nSV = 15
# Kernel = linear; C = 10.0; epsilon =10.0; K = 18
# Accuracy = 90% (9/10) (classification)
#
# ..*.*
# optimization finished, #iter = 71
# nu = 0.000000
# obj = -0.000000, rho = 0.352943
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =0.01; K = 18
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 73
# nu = 0.000000
# obj = -0.000000, rho = 0.352721
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =0.1; K = 18
# Accuracy = 50% (5/10) (classification)
#
# .Kernel = polynomial; C = 0.01; epsilon =1.0; K = 18
# Accuracy = 50% (5/10) (classification)
#
# .*.*
# optimization finished, #iter = 67
# nu = 0.000000
# obj = -0.000000, rho = 0.352568
# nSV = 19, nBSV = 0
# Total nSV = 19
# ..*.*
# optimization finished, #iter = 73
# nu = 0.000000
# obj = -0.000000, rho = 0.351459
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.01; epsilon =10.0; K = 18
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 78
# nu = 0.000000
# obj = -0.000000, rho = 0.352460
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =0.01; K = 18
# Accuracy = 50% (5/10) (classification)
# ..*.*
# optimization finished, #iter = 71
# nu = 0.000000
# obj = -0.000000, rho = 0.352483
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =0.1; K = 18
# Accuracy = 50% (5/10) (classification)
#
# .Kernel = polynomial; C = 0.1; epsilon =1.0; K = 18
# .*.*
# optimization finished, #iter = 66
# nu = 0.000000
# obj = -0.000000, rho = 0.352754
# nSV = 19, nBSV = 0
# Total nSV = 19
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 68
# nu = 0.000000
# obj = -0.000000, rho = 0.352623
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 0.1; epsilon =10.0; K = 18
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 74
# nu = 0.000000
# obj = -0.000000, rho = 0.352626
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =0.01; K = 18
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 72
# nu = 0.000000
# obj = -0.000000, rho = 0.352670
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =0.1; K = 18
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 67
# nu = 0.000000
# obj = -0.000000, rho = 0.352490
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =1.0; K = 18
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 72
# nu = 0.000000
# obj = -0.000000, rho = 0.352499
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 1.0; epsilon =10.0; K = 18
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 74
# nu = 0.000000
# obj = -0.000000, rho = 0.352509
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =0.01; K = 18
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 66
# nu = 0.000000
# obj = -0.000000, rho = 0.352983
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =0.1; K = 18
# Accuracy = 50% (5/10) (classification)
#
# .Kernel = polynomial; C = 10.0; epsilon =1.0; K = 18
# .*.*
# optimization finished, #iter = 66
# nu = 0.000000
# obj = -0.000000, rho = 0.352816
# nSV = 19, nBSV = 0
# Total nSV = 19
# Accuracy = 50% (5/10) (classification)
#
# ..*.*
# optimization finished, #iter = 69
# nu = 0.000000
# obj = -0.000000, rho = 0.352912
# nSV = 19, nBSV = 0
# Total nSV = 19
# Kernel = polynomial; C = 10.0; epsilon =10.0; K = 18
# Accuracy = 50% (5/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =0.01; K = 18
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =0.1; K = 18
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =1.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# *.*
# optimization finished, #iter = 23
# nu = 0.900000
# obj = -0.179182, rho = 0.991818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.01; epsilon =10.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =0.01; K = 18
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =0.1; K = 18
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =1.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 30
# nu = 0.900000
# obj = -1.718181, rho = 0.918182
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 0.1; epsilon =10.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =0.01; K = 18
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =0.1; K = 18
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =1.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# .*
# optimization finished, #iter = 39
# nu = 0.900000
# obj = -9.818181, rho = 0.181818
# nSV = 20, nBSV = 9
# Total nSV = 20
# Kernel = RBF; C = 1.0; epsilon =10.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# ..*.Kernel = RBF; C = 10.0; epsilon =0.01; K = 18
# *
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# Kernel = RBF; C = 10.0; epsilon =0.1; K = 18
# Accuracy = 40% (4/10) (classification)
#
# ..*.*
# optimization finished, #iter = 63
# Kernel = RBF; C = 10.0; epsilon =1.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# .Kernel = RBF; C = 10.0; epsilon =10.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# .*.*
# optimization finished, #iter = 63
# nu = 0.099004
# obj = -9.899998, rho = 0.100000
# nSV = 20, nBSV = 0
# Total nSV = 20
# *
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179200, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =0.01; K = 18
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179200, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =0.1; K = 18
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179200, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =1.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 11
# nu = 0.900000
# obj = -0.179200, rho = 0.970000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.01; epsilon =10.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# Kernel = Sigmoid; C = 0.1; epsilon =0.01; K = 18*
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.720000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
#
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.720000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =0.1; K = 18
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.720000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =1.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 12
# nu = 0.900000
# obj = -1.720000, rho = 0.700000
# nSV = 18, nBSV = 18
# Total nSV = 18
# Kernel = Sigmoid; C = 0.1; epsilon =10.0; K = 18
# Accuracy = 40% (4/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =0.01; K = 18
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =0.1; K = 18
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =1.0; K = 18
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 5
# nu = 0.500000
# obj = -18.000000, rho = -1.000000
# nSV = 10, nBSV = 10
# Total nSV = 10
# Kernel = Sigmoid; C = 1.0; epsilon =10.0; K = 18
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Kernel = Sigmoid; C = 10.0; epsilon =0.01; K = 18
# Accuracy = 80% (8/10) (classification)
# *
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Kernel = Sigmoid; C = 10.0; epsilon =0.1; K = 18
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Kernel = Sigmoid; C = 10.0; epsilon =1.0; K = 18
# Accuracy = 80% (8/10) (classification)
#
# *
# optimization finished, #iter = 6
# nu = 0.455000
# obj = -940.500000, rho = -10.000000
# nSV = 10, nBSV = 8
# Total nSV = 10
# Kernel = Sigmoid; C = 10.0; epsilon =10.0; K = 18
# Accuracy = 80% (8/10) (classification)
#
# Max Accuracy at the following settings with Accuracy = 90.0
# Kernel = linear; C = 0.01; epsilon =0.01; K = 15
# Kernel = linear; C = 0.01; epsilon =0.1; K = 15
# Kernel = linear; C = 0.01; epsilon =1.0; K = 15
# Kernel = linear; C = 0.01; epsilon =10.0; K = 15
# Kernel = linear; C = 0.1; epsilon =0.01; K = 15
# Kernel = linear; C = 0.1; epsilon =0.1; K = 15
# Kernel = linear; C = 0.1; epsilon =1.0; K = 15
# Kernel = linear; C = 0.1; epsilon =10.0; K = 15
# Kernel = linear; C = 1.0; epsilon =0.01; K = 15
# Kernel = linear; C = 1.0; epsilon =0.1; K = 15
# Kernel = linear; C = 1.0; epsilon =1.0; K = 15
# Kernel = linear; C = 1.0; epsilon =10.0; K = 15
# Kernel = linear; C = 10.0; epsilon =0.01; K = 15
# Kernel = linear; C = 10.0; epsilon =0.1; K = 15
# Kernel = linear; C = 10.0; epsilon =1.0; K = 15
# Kernel = linear; C = 10.0; epsilon =10.0; K = 15
# Kernel = Sigmoid; C = 1.0; epsilon =0.01; K = 15
# Kernel = Sigmoid; C = 1.0; epsilon =0.1; K = 15
# Kernel = Sigmoid; C = 1.0; epsilon =1.0; K = 15
# Kernel = Sigmoid; C = 1.0; epsilon =10.0; K = 15
# Kernel = Sigmoid; C = 10.0; epsilon =0.01; K = 15
# Kernel = Sigmoid; C = 10.0; epsilon =0.1; K = 15
# Kernel = Sigmoid; C = 10.0; epsilon =1.0; K = 15
# Kernel = Sigmoid; C = 10.0; epsilon =10.0; K = 15
# Kernel = linear; C = 0.01; epsilon =0.01; K = 16
# Kernel = linear; C = 0.01; epsilon =0.1; K = 16
# Kernel = linear; C = 0.01; epsilon =1.0; K = 16
# Kernel = linear; C = 0.01; epsilon =10.0; K = 16
# Kernel = linear; C = 0.1; epsilon =0.01; K = 16
# Kernel = linear; C = 0.1; epsilon =0.1; K = 16
# Kernel = linear; C = 0.1; epsilon =1.0; K = 16
# Kernel = linear; C = 0.1; epsilon =10.0; K = 16
# Kernel = linear; C = 1.0; epsilon =0.01; K = 16
# Kernel = linear; C = 1.0; epsilon =0.1; K = 16
# Kernel = linear; C = 1.0; epsilon =1.0; K = 16
# Kernel = linear; C = 1.0; epsilon =10.0; K = 16
# Kernel = linear; C = 10.0; epsilon =0.01; K = 16
# Kernel = linear; C = 10.0; epsilon =0.1; K = 16
# Kernel = linear; C = 10.0; epsilon =1.0; K = 16
# Kernel = linear; C = 10.0; epsilon =10.0; K = 16
# Kernel = linear; C = 0.01; epsilon =0.01; K = 17
# Kernel = linear; C = 0.01; epsilon =0.1; K = 17
# Kernel = linear; C = 0.01; epsilon =1.0; K = 17
# Kernel = linear; C = 0.01; epsilon =10.0; K = 17
# Kernel = linear; C = 0.1; epsilon =0.01; K = 17
# Kernel = linear; C = 0.1; epsilon =0.1; K = 17
# Kernel = linear; C = 0.1; epsilon =1.0; K = 17
# Kernel = linear; C = 0.1; epsilon =10.0; K = 17
# Kernel = linear; C = 1.0; epsilon =0.01; K = 17
# Kernel = linear; C = 1.0; epsilon =0.1; K = 17
# Kernel = linear; C = 1.0; epsilon =1.0; K = 17
# Kernel = linear; C = 1.0; epsilon =10.0; K = 17
# Kernel = linear; C = 10.0; epsilon =0.01; K = 17
# Kernel = linear; C = 10.0; epsilon =0.1; K = 17
# Kernel = linear; C = 10.0; epsilon =1.0; K = 17
# Kernel = linear; C = 10.0; epsilon =10.0; K = 17
# Kernel = linear; C = 0.01; epsilon =0.01; K = 18
# Kernel = linear; C = 0.01; epsilon =0.1; K = 18
# Kernel = linear; C = 0.01; epsilon =1.0; K = 18
# Kernel = linear; C = 0.01; epsilon =10.0; K = 18
# Kernel = linear; C = 0.1; epsilon =0.01; K = 18
# Kernel = linear; C = 0.1; epsilon =0.1; K = 18
# Kernel = linear; C = 0.1; epsilon =1.0; K = 18
# Kernel = linear; C = 0.1; epsilon =10.0; K = 18
# Kernel = linear; C = 1.0; epsilon =0.01; K = 18
# Kernel = linear; C = 1.0; epsilon =0.1; K = 18
# Kernel = linear; C = 1.0; epsilon =1.0; K = 18
# Kernel = linear; C = 1.0; epsilon =10.0; K = 18
# Kernel = linear; C = 10.0; epsilon =0.01; K = 18
# Kernel = linear; C = 10.0; epsilon =0.1; K = 18
# Kernel = linear; C = 10.0; epsilon =1.0; K = 18
# Kernel = linear; C = 10.0; epsilon =10.0; K = 18

# %% [markdown]
# With Kernel SVM, I'm getting highest accuracy of 90% with the following settings printed above in bold. Summarizing that, we get maximum accuracy when kernel type is LINEAR, and value of K ranges from 15 to 18. However, for this data set, the different values of C and epsilon does not change the accuracy given LINEAR Kernel and K = [15, 18]

# %% [markdown]
# # PART B: LDA vs SVM

# %%
for k in range(1,30):
    tempObj = usingLIBSVM(k, 0, 0.1, 0.1)                          #Creating object to get Dim. Reduced Data from PCA
    trainData, testData = tempObj.getReducedData()
    lda = LinearDiscriminantAnalysis(n_components = 1)
    lda.fit(trainData, y)
    acc = findAccuracy(list(lda.predict(testData)))
    if (acc >= 90.0):
        print('\033[1m'+"Accuracy = ",acc, "% at K =", k,'\033[0m')
    else:
        print("Accuracy = ",acc, "% at K =", k)
# Out:
# Accuracy =  40.0 % at K = 1
# Accuracy =  40.0 % at K = 2
# Accuracy =  60.0 % at K = 3
# Accuracy =  60.0 % at K = 4
# Accuracy =  80.0 % at K = 5
# Accuracy =  100.0 % at K = 6
# Accuracy =  70.0 % at K = 7
# Accuracy =  80.0 % at K = 8
# Accuracy =  80.0 % at K = 9
# Accuracy =  90.0 % at K = 10
# Accuracy =  80.0 % at K = 11
# Accuracy =  70.0 % at K = 12
# Accuracy =  60.0 % at K = 13
# Accuracy =  60.0 % at K = 14
# Accuracy =  60.0 % at K = 15
# Accuracy =  60.0 % at K = 16
# Accuracy =  60.0 % at K = 17
# Accuracy =  70.0 % at K = 18
# Accuracy =  70.0 % at K = 19
# Accuracy =  80.0 % at K = 20
# Accuracy =  40.0 % at K = 21
# Accuracy =  60.0 % at K = 22
# Accuracy =  60.0 % at K = 23
# Accuracy =  60.0 % at K = 24
# Accuracy =  40.0 % at K = 25
# Accuracy =  50.0 % at K = 26
# Accuracy =  20.0 % at K = 27
# Accuracy =  40.0 % at K = 28
# Accuracy =  40.0 % at K = 29

# %% [markdown]
# Maximum performance obatined by SVM is 90% where as by LDA, I'm are getting a maximum of 100% accuracy at K = 6.

# %% [markdown]
# LDA seperates the data such that mean of classes is well seperated, whereas, SVM chooses a hyperplane which maximizes the margin. SVM using kernel performs very good with higher dimensional data where as LDA doesn't perform that good
